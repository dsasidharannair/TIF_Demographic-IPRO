# %%
import json
from shapely.geometry import shape, MultiPolygon, Polygon, mapping
from shapely.ops import unary_union
from shapely.validation import explain_validity
import pandas as pd
import geopandas as gpd
from shapely import wkt
from branca.colormap import linear
from branca.colormap import LinearColormap
import folium

# %%
data = pd.read_csv('merged_file.csv')

data['geometry'] = data['geometry'].apply(wkt.loads)

gdf = gpd.GeoDataFrame(data, geometry='geometry')

gdf.to_file('merged.geojson', driver='GeoJSON')

# %%
import json
from shapely.geometry import shape, MultiPolygon, Polygon, mapping
from shapely.ops import unary_union
from shapely.validation import explain_validity

def validate_and_fix(geom):
    if not geom.is_valid:
        print("Invalid geometry:", explain_validity(geom))
        return geom.buffer(0)
    return geom

def simplify(geom):
    return geom.simplify(0.1, preserve_topology=True)

with open('merged.geojson') as f1:
    data1 = json.load(f1)

with open('Boundaries - TIF.geojson') as f2:
    data2 = json.load(f2)

geoms1 = [validate_and_fix(simplify(shape(feature['geometry']))) for feature in data1['features']]
geoms2 = [validate_and_fix(simplify(shape(feature['geometry']))) for feature in data2['features']]

output_features = []

for geom1, prop1 in zip(geoms1, data1['features']):
    intersecting_parts = []
    for geom2 in geoms2:
        if geom1.intersects(geom2):
            intersection = geom1.intersection(geom2)
            if isinstance(intersection, MultiPolygon):
                intersecting_parts.extend(list(intersection.geoms))
            elif isinstance(intersection, Polygon):
                intersecting_parts.append(intersection)

    non_intersecting_parts = geom1
    for part in intersecting_parts:
        non_intersecting_parts = non_intersecting_parts.difference(part)

    if isinstance(non_intersecting_parts, MultiPolygon):
        for part in non_intersecting_parts.geoms:
            ratio = part.area / geom1.area
            output_features.append({
                'type': 'Feature',
                'geometry': mapping(part),
                'properties': {**prop1['properties'], 'ratio_to_original': ratio},
            })
    elif isinstance(non_intersecting_parts, Polygon):
        ratio = non_intersecting_parts.area / geom1.area
        output_features.append({
            'type': 'Feature',
            'geometry': mapping(non_intersecting_parts),
            'properties': {**prop1['properties'], 'ratio_to_original': ratio},
        })

output_geojson = {
    'type': 'FeatureCollection',
    'features': output_features
}

with open('non_intersecting_geojson_file.geojson', 'w') as output_file:
    json.dump(output_geojson, output_file)

# %%
with open("non_intersecting_geojson_file.geojson") as f:
    census_txt = f.read()

census_tracts = json.loads(census_txt)

# %%
filtered_data = data.dropna(subset=["Median_Household_Income"])
min_income = filtered_data["Median_Household_Income"].min()
max_income = filtered_data["Median_Household_Income"].max()
colormap = linear.RdYlGn_11.scale(min_income, max_income)
colormap
# Out:
# <svg height="40" width="450"><line x1="0" y1="15" x2="0" y2="27" style="stroke:#a50026ff;stroke-width:2;" /><line x1="1" y1="15" x2="1" y2="27" style="stroke:#a60126ff;stroke-width:2;" /><line x1="2" y1="15" x2="2" y2="27" style="stroke:#a70226ff;stroke-width:2;" /><line x1="3" y1="15" x2="3" y2="27" style="stroke:#a90326ff;stroke-width:2;" /><line x1="4" y1="15" x2="4" y2="27" style="stroke:#aa0426ff;stroke-width:2;" /><line x1="5" y1="15" x2="5" y2="27" style="stroke:#ab0526ff;stroke-width:2;" /><line x1="6" y1="15" x2="6" y2="27" style="stroke:#ac0626ff;stroke-width:2;" /><line x1="7" y1="15" x2="7" y2="27" style="stroke:#ad0726ff;stroke-width:2;" /><line x1="8" y1="15" x2="8" y2="27" style="stroke:#ae0826ff;stroke-width:2;" /><line x1="9" y1="15" x2="9" y2="27" style="stroke:#af0926ff;stroke-width:2;" /><line x1="10" y1="15" x2="10" y2="27" style="stroke:#b00a26ff;stroke-width:2;" /><line x1="11" y1="15" x2="11" y2="27" style="stroke:#b10b26ff;stroke-width:2;" /><line x1="12" y1="15" x2="12" y2="27" style="stroke:#b30c26ff;stroke-width:2;" /><line x1="13" y1="15" x2="13" y2="27" style="stroke:#b40d26ff;stroke-width:2;" /><line x1="14" y1="15" x2="14" y2="27" style="stroke:#b50f26ff;stroke-width:2;" /><line x1="15" y1="15" x2="15" y2="27" style="stroke:#b61026ff;stroke-width:2;" /><line x1="16" y1="15" x2="16" y2="27" style="stroke:#b71126ff;stroke-width:2;" /><line x1="17" y1="15" x2="17" y2="27" style="stroke:#b81226ff;stroke-width:2;" /><line x1="18" y1="15" x2="18" y2="27" style="stroke:#b91326ff;stroke-width:2;" /><line x1="19" y1="15" x2="19" y2="27" style="stroke:#ba1426ff;stroke-width:2;" /><line x1="20" y1="15" x2="20" y2="27" style="stroke:#bc1526ff;stroke-width:2;" /><line x1="21" y1="15" x2="21" y2="27" style="stroke:#bd1626ff;stroke-width:2;" /><line x1="22" y1="15" x2="22" y2="27" style="stroke:#be1726ff;stroke-width:2;" /><line x1="23" y1="15" x2="23" y2="27" style="stroke:#bf1826ff;stroke-width:2;" /><line x1="24" y1="15" x2="24" y2="27" style="stroke:#c01926ff;stroke-width:2;" /><line x1="25" y1="15" x2="25" y2="27" style="stroke:#c11a26ff;stroke-width:2;" /><line x1="26" y1="15" x2="26" y2="27" style="stroke:#c21b26ff;stroke-width:2;" /><line x1="27" y1="15" x2="27" y2="27" style="stroke:#c31c26ff;stroke-width:2;" /><line x1="28" y1="15" x2="28" y2="27" style="stroke:#c41e26ff;stroke-width:2;" /><line x1="29" y1="15" x2="29" y2="27" style="stroke:#c61f26ff;stroke-width:2;" /><line x1="30" y1="15" x2="30" y2="27" style="stroke:#c72026ff;stroke-width:2;" /><line x1="31" y1="15" x2="31" y2="27" style="stroke:#c82126ff;stroke-width:2;" /><line x1="32" y1="15" x2="32" y2="27" style="stroke:#c92226ff;stroke-width:2;" /><line x1="33" y1="15" x2="33" y2="27" style="stroke:#ca2326ff;stroke-width:2;" /><line x1="34" y1="15" x2="34" y2="27" style="stroke:#cb2426ff;stroke-width:2;" /><line x1="35" y1="15" x2="35" y2="27" style="stroke:#cc2526ff;stroke-width:2;" /><line x1="36" y1="15" x2="36" y2="27" style="stroke:#cd2626ff;stroke-width:2;" /><line x1="37" y1="15" x2="37" y2="27" style="stroke:#cf2726ff;stroke-width:2;" /><line x1="38" y1="15" x2="38" y2="27" style="stroke:#d02826ff;stroke-width:2;" /><line x1="39" y1="15" x2="39" y2="27" style="stroke:#d12927ff;stroke-width:2;" /><line x1="40" y1="15" x2="40" y2="27" style="stroke:#d22a27ff;stroke-width:2;" /><line x1="41" y1="15" x2="41" y2="27" style="stroke:#d32c27ff;stroke-width:2;" /><line x1="42" y1="15" x2="42" y2="27" style="stroke:#d42d27ff;stroke-width:2;" /><line x1="43" y1="15" x2="43" y2="27" style="stroke:#d52e27ff;stroke-width:2;" /><line x1="44" y1="15" x2="44" y2="27" style="stroke:#d62f27ff;stroke-width:2;" /><line x1="45" y1="15" x2="45" y2="27" style="stroke:#d73027ff;stroke-width:2;" /><line x1="46" y1="15" x2="46" y2="27" style="stroke:#d83127ff;stroke-width:2;" /><line x1="47" y1="15" x2="47" y2="27" style="stroke:#d93328ff;stroke-width:2;" /><line x1="48" y1="15" x2="48" y2="27" style="stroke:#d93429ff;stroke-width:2;" /><line x1="49" y1="15"  ...

# %%
pop_dict = filtered_data.set_index("name10")["Median_Household_Income"]

# %%
name10 = census_tracts['features'][0]["properties"]["name10"]
income = pop_dict.get(name10)
income
# Out:
# 68196.0

# %%
m = folium.Map([43, -100], zoom_start=7)

popup = folium.GeoJsonPopup(fields=["namelsad10","Median_Household_Income","ratio_to_original"])

folium.GeoJson(census_tracts,style_function=lambda feature: {
        "fillColor": colormap(pop_dict[feature["properties"]["name10"]]) if feature["properties"]["name10"] in pop_dict else 'gray',
        "color": "black",
        "weight": 1,
        "dashArray": "5, 5",
        "fillOpacity": 0.8,
    },
    popup=popup).add_to(m)

colormap.caption = "Income Color Scale"
colormap.add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d840f9d57a0aefce5f05d3a0a9467686 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d840f9d57a0aefce5f05d3a0a9467686&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d840f9d57a0aefce5f05d3a0a9467686 = L.map(
#                 &quot;map_d840f9d57a0aefce5f05d3a0a9467686&quot;,
#                 {
#                     center: [43.0, -100.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_924044649e4095082fa79f085e0edbc8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d840f9d57a0aefce5f05d3a0a9467686);
#
#
#         function geo_json_ae29a41fab53506a14e871a0dfecf742_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;529&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#f7814cff&quot;, &quot;fillOpacity&quot;: 0.8, &quot;weight&quot;: 1};
#                 case &quot;1&quot;: case &quot;19&quot;: case &quot;236&quot;: case &quot;244&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#f56e43ff&quot;, &quot;fillOpacity&quot;: 0.8, &quot;weight&quot;: 1};
#                 case &quot;2&quot;: case &quot;294&quot;: case &quot;443&quot;: case &quot;807&quot;: case &quot;808&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#f26840ff&quot;, &quot;fillOpacity&quot;: 0.8, &quot;weight&quot;: 1};
#                 case &quot;3&quot;: case &quot;257&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#f7824cff&quot;, &quot;fillOpacity&quot;: 0.8, &quot;weight&quot;: 1};
#                 case &quot;4&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#e64e34ff&quot;, &quot;fillOpacity&quot;: 0.8, &quot;weight&quot;: 1};
#                 case &quot;5&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#e54c33ff&quot;, &quot;fillOpacity&quot;: 0.8, &quot;weight&quot;: 1};
#                 case &quot;6&quot;: case &quot;255&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#ee603dff&quot;, &quot;fillOpacity&quot;: 0.8, &quot;weight&quot;: 1};
#                 case &quot;7&quot;: case &quot;780&quot;: case &quot;781&quot;: case &quot;813&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#b00a26ff&quot;, &quot;fillOpacity&quot;: 0.8, &quot;weight&quot;: 1};
#                 case &quot;8&quot;: case &quot;178&quot;: case &quot;861&quot;: case &quot;862&quot;: case &quot;863&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#f77c4aff&quot;, &quot;fillOpacity&quot;: 0.8, &quot;weight&quot;: 1};
#                 case &quot;9&quot;: case &quot;221&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#f8884fff&quot;, &quot;fillOpacity&quot;: 0.8, &quot;weight&quot;: 1};
#                 case &quot;10&quot;: case &quot;247&quot;: case &quot;409&quot;: case &quot;566&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#ea5739ff&quot;, &quot;fillOpacity&quot;: 0.8, &quot;weight&quot;: 1};
#                 case &quot;11&quot;: case &quot;393&quot;: case &quot;536&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&
